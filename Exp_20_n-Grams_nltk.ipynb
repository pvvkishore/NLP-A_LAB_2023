# %%
import nltk
from nltk.util import ngrams

# %%
list(ngrams(['i', 'have', 'a', 'dream', '[END]'], 2))
# Out:
# [('i', 'have'), ('have', 'a'), ('a', 'dream'), ('dream', '[END]')]

# %%
def extract_ngrams(data, num):
    n_grams = ngrams(nltk.word_tokenize(data), num)
    return [ ' '.join(grams) for grams in n_grams]
 
data = 'I will eat chinese food today in India.'
 
print("1-gram: ", extract_ngrams(data, 1))
print("2-gram: ", extract_ngrams(data, 2))
print("3-gram: ", extract_ngrams(data, 3))
print("4-gram: ", extract_ngrams(data, 4))
# Out:
# 1-gram:  ['I', 'will', 'eat', 'chinese', 'food', 'today', 'in', 'India', '.']
# 2-gram:  ['I will', 'will eat', 'eat chinese', 'chinese food', 'food today', 'today in', 'in India', 'India .']
# 3-gram:  ['I will eat', 'will eat chinese', 'eat chinese food', 'chinese food today', 'food today in', 'today in India', 'in India .']
# 4-gram:  ['I will eat chinese', 'will eat chinese food', 'eat chinese food today', 'chinese food today in', 'food today in India', 'today in India .']

# %%
from nltk.corpus import brown

# %%
print(brown.words())
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
v=nltk.corpus.webtext.words()

# %%
len(v)
# Out:
# 396733

# %%
nltk.corpus.webtext.words()[396]
# Out:
# 'would'

# %%
n_grams = list(ngrams(v,5))

# %%
zip(*n_grams) # Unzipping the zip file

# %%
n_grams
# Out:
# [('Cookie', 'Manager', ':', '"', 'Don'),
#  ('Manager', ':', '"', 'Don', "'"),
#  (':', '"', 'Don', "'", 't'),
#  ('"', 'Don', "'", 't', 'allow'),
#  ('Don', "'", 't', 'allow', 'sites'),
#  ("'", 't', 'allow', 'sites', 'that'),
#  ('t', 'allow', 'sites', 'that', 'set'),
#  ('allow', 'sites', 'that', 'set', 'removed'),
#  ('sites', 'that', 'set', 'removed', 'cookies'),
#  ('that', 'set', 'removed', 'cookies', 'to'),
#  ('set', 'removed', 'cookies', 'to', 'set'),
#  ('removed', 'cookies', 'to', 'set', 'future'),
#  ('cookies', 'to', 'set', 'future', 'cookies'),
#  ('to', 'set', 'future', 'cookies', '"'),
#  ('set', 'future', 'cookies', '"', 'should'),
#  ('future', 'cookies', '"', 'should', 'stay'),
#  ('cookies', '"', 'should', 'stay', 'checked'),
#  ('"', 'should', 'stay', 'checked', 'When'),
#  ('should', 'stay', 'checked', 'When', 'in'),
#  ('stay', 'checked', 'When', 'in', 'full'),
#  ('checked', 'When', 'in', 'full', 'screen'),
#  ('When', 'in', 'full', 'screen', 'mode'),
#  ('in', 'full', 'screen', 'mode', 'Pressing'),
#  ('full', 'screen', 'mode', 'Pressing', 'Ctrl'),
#  ('screen', 'mode', 'Pressing', 'Ctrl', '-'),
#  ('mode', 'Pressing', 'Ctrl', '-', 'N'),
#  ('Pressing', 'Ctrl', '-', 'N', 'should'),
#  ('Ctrl', '-', 'N', 'should', 'open'),
#  ('-', 'N', 'should', 'open', 'a'),
#  ('N', 'should', 'open', 'a', 'new'),
#  ('should', 'open', 'a', 'new', 'browser'),
#  ('open', 'a', 'new', 'browser', 'when'),
#  ('a', 'new', 'browser', 'when', 'only'),
#  ('new', 'browser', 'when', 'only', 'download'),
#  ('browser', 'when', 'only', 'download', 'dialog'),
#  ('when', 'only', 'download', 'dialog', 'is'),
#  ('only', 'download', 'dialog', 'is', 'left'),
#  ('download', 'dialog', 'is', 'left', 'open'),
#  ('dialog', 'is', 'left', 'open', 'add'),
#  ('is', 'left', 'open', 'add', 'icons'),
#  ('left', 'open', 'add', 'icons', 'to'),
#  ('open', 'add', 'icons', 'to', 'context'),
#  ('add', 'icons', 'to', 'context', 'menu'),
#  ('icons', 'to', 'context', 'menu', 'So'),
#  ('to', 'context', 'menu', 'So', 'called'),
#  ('context', 'menu', 'So', 'called', '"'),
#  ('menu', 'So', 'called', '"', 'tab'),
#  ('So', 'called', '"', 'tab', 'bar'),
#  ('called', '"', 'tab', 'bar', '"'),
#  ('"', 'tab', 'bar', '"', 'should'),
#  ('tab', 'bar', '"', 'should', 'be'),
#  ('bar', '"', 'should', 'be', 'made'),
#  ('"', 'should', 'be', 'made', 'a'),
#  ('should', 'be', 'made', 'a', 'proper'),
#  ('be', 'made', 'a', 'proper', 'toolbar'),
#  ('made', 'a', 'proper', 'toolbar', 'or'),
#  ('a', 'proper', 'toolbar', 'or', 'given'),
#  ('proper', 'toolbar', 'or', 'given', 'the'),
#  ('toolbar', 'or', 'given', 'the', 'ability'),
#  ('or', 'given', 'the', 'ability', 'collapse'),
#  ('given', 'the', 'ability', 'collapse', '/'),
#  ('the', 'ability', 'collapse', '/', 'expand'),
#  ('ability', 'collapse', '/', 'expand', '.'),
#  ('collapse', '/', 'expand', '.', '['),
#  ('/', 'expand', '.', '[', 'XUL'),
#  ('expand', '.', '[', 'XUL', ']'),
#  ('.', '[', 'XUL', ']', 'Implement'),
#  ('[', 'XUL', ']', 'Implement', 'Cocoa'),
#  ('XUL', ']', 'Implement', 'Cocoa', '-'),
#  (']', 'Implement', 'Cocoa', '-', 'style'),
#  ('Implement', 'Cocoa', '-', 'style', 'toolbar'),
#  ('Cocoa', '-', 'style', 'toolbar', 'customization'),
#  ('-', 'style', 'toolbar', 'customization', '.'),
#  ('style', 'toolbar', 'customization', '.', '#'),
#  ('toolbar', 'customization', '.', '#', 'ifdefs'),
#  ('customization', '.', '#', 'ifdefs', 'for'),
#  ('.', '#', 'ifdefs', 'for', 'MOZ_PHOENIX'),
#  ('#', 'ifdefs', 'for', 'MOZ_PHOENIX', 'customize'),
#  ('ifdefs', 'for', 'MOZ_PHOENIX', 'customize', 'dialog'),
#  ('for', 'MOZ_PHOENIX', 'customize', 'dialog', "'"),
#  ('MOZ_PHOENIX', 'customize', 'dialog', "'", 's'),
#  ('customize', 'dialog', "'", 's', 'toolbar'),
#  ('dialog', "'", 's', 'toolbar', 'has'),
#  ("'", 's', 'toolbar', 'has', 'small'),
#  ('s', 'toolbar', 'has', 'small', 'icons'),
#  ('toolbar', 'has', 'small', 'icons', 'when'),
#  ('has', 'small', 'icons', 'when', 'small'),
#  ('small', 'icons', 'when', 'small', 'icons'),
#  ('icons', 'when', 'small', 'icons', 'is'),
#  ('when', 'small', 'icons', 'is', 'not'),
#  ('small', 'icons', 'is', 'not', 'checked'),
#  ('icons', 'is', 'not', 'checked', 'nightly'),
#  ('is', 'not', 'checked', 'nightly', 'builds'),
#  ('not', 'checked', 'nightly', 'builds', 'and'),
#  ('checked', 'nightly', 'builds', 'and', 'tinderboxen'),
#  ('nightly', 'builds', 'and', 'tinderboxen', 'for'),
#  ('builds', 'and', 'tinderboxen', 'for', 'Phoenix'),
#  ('and', 'tinderboxen', 'for', 'Phoenix', 'finish'),
#  ('tinderboxen', 'for', 'Phoenix', 'finish', 'tearing'),
#  ('for', 'Phoenix', 'finish', 'tearing', 'prefs'),
#  ('Phoenix', 'finish', 'tearing', 'prefs', 'UI'),
#  ('finish', 'tearing', 'prefs', 'UI', 'to'),
#  ('tearing', 'prefs', 'UI', 'to', 'pieces'),
#  ('prefs', 'UI', 'to', 'pieces', 'and'),
#  ('UI', 'to', 'pieces', 'and', 'then'),
#  ('to', 'pieces', 'and', 'then', 'make'),
#  ('pieces', 'and', 'then', 'make', 'it'),
#  ('and', 'then', 'make', 'it', 'not'),
#  ('then', 'make', 'it', 'not', 'suck'),
#  ('make', 'it', 'not', 'suck', '"'),
#  ('it', 'not', 'suck', '"', 'mozbrowser'),
#  ('not', 'suck', '"', 'mozbrowser', '"'),
#  ('suck', '"', 'mozbrowser', '"', 'script'),
#  ('"', 'mozbrowser', '"', 'script', 'doesn'),
#  ('mozbrowser', '"', 'script', 'doesn', "'"),
#  ('"', 'script', 'doesn', "'", 't'),
#  ('script', 'doesn', "'", 't', 'start'),
#  ('doesn', "'", 't', 'start', 'correct'),
#  ("'", 't', 'start', 'correct', 'binary'),
#  ('t', 'start', 'correct', 'binary', 'Need'),
#  ('start', 'correct', 'binary', 'Need', 'bookmark'),
#  ('correct', 'binary', 'Need', 'bookmark', 'groups'),
#  ('binary', 'Need', 'bookmark', 'groups', 'icon'),
#  ('Need', 'bookmark', 'groups', 'icon', 'Dropping'),
#  ('bookmark', 'groups', 'icon', 'Dropping', 'at'),
#  ('groups', 'icon', 'Dropping', 'at', 'top'),
#  ('icon', 'Dropping', 'at', 'top', 'of'),
#  ('Dropping', 'at', 'top', 'of', 'palette'),
#  ('at', 'top', 'of', 'palette', 'box'),
#  ('top', 'of', 'palette', 'box', 'horks'),
#  ('of', 'palette', 'box', 'horks', 'things'),
#  ('palette', 'box', 'horks', 'things', 'keyboard'),
#  ('box', 'horks', 'things', 'keyboard', 'shortcut'),
#  ('horks', 'things', 'keyboard', 'shortcut', 'for'),
#  ('things', 'keyboard', 'shortcut', 'for', 'Increase'),
#  ('keyboard', 'shortcut', 'for', 'Increase', 'Text'),
#  ('shortcut', 'for', 'Increase', 'Text', 'Size'),
#  ('for', 'Increase', 'Text', 'Size', 'is'),
#  ('Increase', 'Text', 'Size', 'is', 'broken'),
#  ('Text', 'Size', 'is', 'broken', 'default'),
#  ('Size', 'is', 'broken', 'default', 'phoenix'),
#  ('is', 'broken', 'default', 'phoenix', 'bookmarks'),
#  ('broken', 'default', 'phoenix', 'bookmarks', '['),
#  ('default', 'phoenix', 'bookmarks', '[', 'cust'),
#  ('phoenix', 'bookmarks', '[', 'cust', ']'),
#  ('bookmarks', '[', 'cust', ']', 'need'),
#  ('[', 'cust', ']', 'need', 'a'),
#  ('cust', ']', 'need', 'a', 'toolbar'),
#  (']', 'need', 'a', 'toolbar', 'spacer'),
#  ('need', 'a', 'toolbar', 'spacer', 'and'),
#  ('a', 'toolbar', 'spacer', 'and', 'spring'),
#  ('toolbar', 'spacer', 'and', 'spring', 'spacer'),
#  ('spacer', 'and', 'spring', 'spacer', 'for'),
#  ('and', 'spring', 'spacer', 'for', 'customize'),
#  ('spring', 'spacer', 'for', 'customize', 'Can'),
#  ('spacer', 'for', 'customize', 'Can', "'"),
#  ('for', 'customize', 'Can', "'", 't'),
#  ('customize', 'Can', "'", 't', 'launch'),
#  ('Can', "'", 't', 'launch', 'phoenix'),
#  ("'", 't', 'launch', 'phoenix', 'while'),
#  ('t', 'launch', 'phoenix', 'while', 'Mozilla'),
#  ('launch', 'phoenix', 'while', 'Mozilla', 'is'),
#  ('phoenix', 'while', 'Mozilla', 'is', 'running'),
#  ('while', 'Mozilla', 'is', 'running', '('),
#  ('Mozilla', 'is', 'running', '(', 'or'),
#  ('is', 'running', '(', 'or', 'vice'),
#  ('running', '(', 'or', 'vice', 'versa'),
#  ('(', 'or', 'vice', 'versa', ')'),
#  ('or', 'vice', 'versa', ')', 'separator'),
#  ('vice', 'versa', ')', 'separator', 'not'),
#  ('versa', ')', 'separator', 'not', 'available'),
#  (')', 'separator', 'not', 'available', 'when'),
#  ('separator', 'not', 'available', 'when', 'all'),
#  ('not', 'available', 'when', 'all', 'toolbar'),
#  ('available', 'when', 'all', 'toolbar', 'items'),
#  ('when', 'all', 'toolbar', 'items', 'are'),
#  ('all', 'toolbar', 'items', 'are', 'in'),
#  ('toolbar', 'items', 'are', 'in', 'toolbar'),
#  ('items', 'are', 'in', 'toolbar', 'layout'),
#  ('are', 'in', 'toolbar', 'layout', 'history'),
#  ('in', 'toolbar', 'layout', 'history', 'menu'),
#  ('toolbar', 'layout', 'history', 'menu', 'for'),
#  ('layout', 'history', 'menu', 'for', 'the'),
#  ('history', 'menu', 'for', 'the', 'back'),
#  ('menu', 'for', 'the', 'back', 'buttons'),
#  ('for', 'the', 'back', 'buttons', 'doesn'),
#  ('the', 'back', 'buttons', 'doesn', "'"),
#  ('back', 'buttons', 'doesn', "'", 't'),
#  ('buttons', 'doesn', "'", 't', 'work'),
#  ('doesn', "'", 't', 'work', 'attempting'),
#  ("'", 't', 'work', 'attempting', 'to'),
#  ('t', 'work', 'attempting', 'to', 'open'),
#  ('work', 'attempting', 'to', 'open', '"'),
#  ('attempting', 'to', 'open', '"', 'back'),
#  ('to', 'open', '"', 'back', 'button'),
#  ('open', '"', 'back', 'button', 'history'),
#  ('"', 'back', 'button', 'history', 'menu'),
#  ('back', 'button', 'history', 'menu', '"'),
#  ('button', 'history', 'menu', '"', 'in'),
#  ('history', 'menu', '"', 'in', 'the'),
#  ('menu', '"', 'in', 'the', 'second'),
#  ('"', 'in', 'the', 'second', 'window'),
#  ('in', 'the', 'second', 'window', 'generates'),
#  ('the', 'second', 'window', 'generates', 'another'),
#  ('second', 'window', 'generates', 'another', 'back'),
#  ('window', 'generates', 'another', 'back', 'button'),
#  ('generates', 'another', 'back', 'button', 'on'),
#  ('another', 'back', 'button', 'on', 'the'),
#  ('back', 'button', 'on', 'the', 'toolbar'),
#  ('button', 'on', 'the', 'toolbar', 'Phoenix'),
#  ('on', 'the', 'toolbar', 'Phoenix', 'and'),
#  ('the', 'toolbar', 'Phoenix', 'and', 'Mozilla'),
#  ('toolbar', 'Phoenix', 'and', 'Mozilla', 'cannot'),
#  ('Phoenix', 'and', 'Mozilla', 'cannot', 'comfortably'),
#  ('and', 'Mozilla', 'cannot', 'comfortably', 'share'),
#  ('Mozilla', 'cannot', 'comfortably', 'share', 'a'),
#  ('cannot', 'comfortably', 'share', 'a', 'source'),
#  ('comfortably', 'share', 'a', 'source', 'tree'),
#  ('share', 'a', 'source', 'tree', 'Phoenix'),
#  ('a', 'source', 'tree', 'Phoenix', 'forgets'),
#  ('source', 'tree', 'Phoenix', 'forgets', 'all'),
#  ('tree', 'Phoenix', 'forgets', 'all', 'cookies'),
#  ('Phoenix', 'forgets', 'all', 'cookies', 'even'),
#  ('forgets', 'all', 'cookies', 'even', 'though'),
#  ('all', 'cookies', 'even', 'though', '"'),
#  ('cookies', 'even', 'though', '"', 'Enable'),
#  ('even', 'though', '"', 'Enable', 'cookies'),
#  ('though', '"', 'Enable', 'cookies', 'for'),
#  ('"', 'Enable', 'cookies', 'for', 'the'),
#  ('Enable', 'cookies', 'for', 'the', 'current'),
#  ('cookies', 'for', 'the', 'current', 'session'),
#  ('for', 'the', 'current', 'session', 'only'),
#  ('the', 'current', 'session', 'only', '"'),
#  ('current', 'session', 'only', '"', 'is'),
#  ('session', 'only', '"', 'is', 'NOT'),
#  ('only', '"', 'is', 'NOT', 'chosen'),
#  ('"', 'is', 'NOT', 'chosen', 'Starting'),
#  ('is', 'NOT', 'chosen', 'Starting', 'Customizing'),
#  ('NOT', 'chosen', 'Starting', 'Customizing', 'Toolbar'),
#  ('chosen', 'Starting', 'Customizing', 'Toolbar', 'makes'),
#  ('Starting', 'Customizing', 'Toolbar', 'makes', 'the'),
#  ('Customizing', 'Toolbar', 'makes', 'the', 'current'),
#  ('Toolbar', 'makes', 'the', 'current', 'page'),
#  ('makes', 'the', 'current', 'page', 'go'),
#  ('the', 'current', 'page', 'go', 'blank'),
#  ('current', 'page', 'go', 'blank', 'Check'),
#  ('page', 'go', 'blank', 'Check', 'in'),
#  ('go', 'blank', 'Check', 'in', 'Satchel'),
#  ('blank', 'Check', 'in', 'Satchel', '('),
#  ('Check', 'in', 'Satchel', '(', 'the'),
#  ('in', 'Satchel', '(', 'the', 'successor'),
#  ('Satchel', '(', 'the', 'successor', 'to'),
#  ('(', 'the', 'successor', 'to', 'wallet'),
#  ('the', 'successor', 'to', 'wallet', ')'),
#  ('successor', 'to', 'wallet', ')', 'Mousing'),
#  ('to', 'wallet', ')', 'Mousing', 'over'),
#  ('wallet', ')', 'Mousing', 'over', 'back'),
#  (')', 'Mousing', 'over', 'back', 'menu'),
#  ('Mousing', 'over', 'back', 'menu', 'in'),
#  ('over', 'back', 'menu', 'in', 'second'),
#  ('back', 'menu', 'in', 'second', 'window'),
#  ('menu', 'in', 'second', 'window', 'horks'),
#  ('in', 'second', 'window', 'horks', 'things'),
#  ('second', 'window', 'horks', 'things', 'Personal'),
#  ('window', 'horks', 'things', 'Personal', 'toolbar'),
#  ('horks', 'things', 'Personal', 'toolbar', 'needs'),
#  ('things', 'Personal', 'toolbar', 'needs', 'a'),
#  ('Personal', 'toolbar', 'needs', 'a', 'min'),
#  ('toolbar', 'needs', 'a', 'min', '-'),
#  ('needs', 'a', 'min', '-', 'height'),
#  ('a', 'min', '-', 'height', 'to'),
#  ('min', '-', 'height', 'to', 'avoid'),
#  ('-', 'height', 'to', 'avoid', '"'),
#  ('height', 'to', 'avoid', '"', 'popping'),
#  ('to', 'avoid', '"', 'popping', 'in'),
#  ('avoid', '"', 'popping', 'in', '"'),
#  ('"', 'popping', 'in', '"', 'New'),
#  ('popping', 'in', '"', 'New', 'Folder'),
#  ('in', '"', 'New', 'Folder', '...'),
#  ('"', 'New', 'Folder', '...', 'in'),
#  ('New', 'Folder', '...', 'in', 'ptoolbar'),
#  ('Folder', '...', 'in', 'ptoolbar', 'context'),
#  ('...', 'in', 'ptoolbar', 'context', 'menu'),
#  ('in', 'ptoolbar', 'context', 'menu', 'is'),
#  ('ptoolbar', 'context', 'menu', 'is', 'broken'),
#  ('context', 'menu', 'is', 'broken', 'Implement'),
#  ('menu', 'is', 'broken', 'Implement', 'Mozilla'),
#  ('is', 'broken', 'Implement', 'Mozilla', 'Firebird'),
#  ('broken', 'Implement', 'Mozilla', 'Firebird', 'Help'),
#  ('Implement', 'Mozilla', 'Firebird', 'Help', 'tabs'),
#  ('Mozilla', 'Firebird', 'Help', 'tabs', 'close'),
#  ('Firebird', 'Help', 'tabs', 'close', 'in'),
#  ('Help', 'tabs', 'close', 'in', 'the'),
#  ('tabs', 'close', 'in', 'the', 'wrong'),
#  ('close', 'in', 'the', 'wrong', 'order'),
#  ('in', 'the', 'wrong', 'order', '('),
#  ('the', 'wrong', 'order', '(', 'right'),
#  ('wrong', 'order', '(', 'right', 'to'),
#  ('order', '(', 'right', 'to', 'left'),
#  ('(', 'right', 'to', 'left', ')'),
#  ('right', 'to', 'left', ')', 'back'),
#  ('to', 'left', ')', 'back', 'buttons'),
#  ('left', ')', 'back', 'buttons', 'and'),
#  (')', 'back', 'buttons', 'and', 'context'),
#  ('back', 'buttons', 'and', 'context', 'options'),
#  ('buttons', 'and', 'context', 'options', 'always'),
#  ('and', 'context', 'options', 'always', 'disabled'),
#  ('context', 'options', 'always', 'disabled', '.'),
#  ('options', 'always', 'disabled', '.', 'Customising'),
#  ('always', 'disabled', '.', 'Customising', 'toolbar'),
#  ('disabled', '.', 'Customising', 'toolbar', 'breaks'),
#  ('.', 'Customising', 'toolbar', 'breaks', 'the'),
#  ('Customising', 'toolbar', 'breaks', 'the', 'throbber'),
#  ('toolbar', 'breaks', 'the', 'throbber', '!'),
#  ('breaks', 'the', 'throbber', '!', 'manage'),
#  ('the', 'throbber', '!', 'manage', 'bookmarks'),
#  ('throbber', '!', 'manage', 'bookmarks', 'causes'),
#  ('!', 'manage', 'bookmarks', 'causes', 'hang'),
#  ('manage', 'bookmarks', 'causes', 'hang', 'land'),
#  ('bookmarks', 'causes', 'hang', 'land', 'pch'),
#  ('causes', 'hang', 'land', 'pch', "'"),
#  ('hang', 'land', 'pch', "'", 's'),
#  ('land', 'pch', "'", 's', 'bookmarks'),
#  ('pch', "'", 's', 'bookmarks', 'patch'),
#  ("'", 's', 'bookmarks', 'patch', 'from'),
#  ('s', 'bookmarks', 'patch', 'from', 'bug'),
#  ('bookmarks', 'patch', 'from', 'bug', '160019'),
#  ('patch', 'from', 'bug', '160019', 'Preferences'),
#  ('from', 'bug', '160019', 'Preferences', '>'),
#  ('bug', '160019', 'Preferences', '>', 'Privacy'),
#  ('160019', 'Preferences', '>', 'Privacy', '>'),
#  ('Preferences', '>', 'Privacy', '>', 'Images'),
#  ('>', 'Privacy', '>', 'Images', '=='),
#  ('Privacy', '>', 'Images', '==', 'Wonky'),
#  ('>', 'Images', '==', 'Wonky', 'Extremely'),
#  ('Images', '==', 'Wonky', 'Extremely', 'high'),
#  ('==', 'Wonky', 'Extremely', 'high', 'memory'),
#  ('Wonky', 'Extremely', 'high', 'memory', 'consumption'),
#  ('Extremely', 'high', 'memory', 'consumption', 'after'),
#  ('high', 'memory', 'consumption', 'after', 'closing'),
#  ('memory', 'consumption', 'after', 'closing', 'all'),
#  ('consumption', 'after', 'closing', 'all', 'windows'),
#  ('after', 'closing', 'all', 'windows', 'with'),
#  ('closing', 'all', 'windows', 'with', 'Quick'),
#  ('all', 'windows', 'with', 'Quick', 'Launch'),
#  ('windows', 'with', 'Quick', 'Launch', '('),
#  ('with', 'Quick', 'Launch', '(', 'Turbo'),
#  ('Quick', 'Launch', '(', 'Turbo', ')'),
#  ('Launch', '(', 'Turbo', ')', 'enabled'),
#  ('(', 'Turbo', ')', 'enabled', 'Go'),
#  ('Turbo', ')', 'enabled', 'Go', 'menu'),
#  (')', 'enabled', 'Go', 'menu', 'needs'),
#  ('enabled', 'Go', 'menu', 'needs', 'to'),
#  ('Go', 'menu', 'needs', 'to', 'have'),
#  ('menu', 'needs', 'to', 'have', 'an'),
#  ('needs', 'to', 'have', 'an', 'id'),
#  ('to', 'have', 'an', 'id', '='),
#  ('have', 'an', 'id', '=', 'implement'),
#  ('an', 'id', '=', 'implement', 'progress'),
#  ('id', '=', 'implement', 'progress', 'meter'),
#  ('=', 'implement', 'progress', 'meter', 'in'),
#  ('implement', 'progress', 'meter', 'in', 'URLbar'),
#  ('progress', 'meter', 'in', 'URLbar', 'view'),
#  ('meter', 'in', 'URLbar', 'view', 'source'),
#  ('in', 'URLbar', 'view', 'source', 'tries'),
#  ('URLbar', 'view', 'source', 'tries', 'to'),
#  ('view', 'source', 'tries', 'to', 'download'),
#  ('source', 'tries', 'to', 'download', 'type'),
#  ('tries', 'to', 'download', 'type', 'application'),
#  ('to', 'download', 'type', 'application', 'x'),
#  ('download', 'type', 'application', 'x', '-'),
#  ('type', 'application', 'x', '-', 'view'),
#  ('application', 'x', '-', 'view', '-'),
#  ('x', '-', 'view', '-', 'source'),
#  ('-', 'view', '-', 'source', 'from'),
#  ('view', '-', 'source', 'from', 'view'),
#  ('-', 'source', 'from', 'view', '-'),
#  ('source', 'from', 'view', '-', 'source'),
#  ('from', 'view', '-', 'source', ':<'),
#  ('view', '-', 'source', ':<', 'url'),
#  ('-', 'source', ':<', 'url', '>'),
#  ('source', ':<', 'url', '>', 'second'),
#  (':<', 'url', '>', 'second', 'window'),
#  ('url', '>', 'second', 'window', 'opens'),
#  ('>', 'second', 'window', 'opens', 'mozilla'),
#  ('second', 'window', 'opens', 'mozilla', 'fix'),
#  ('window', 'opens', 'mozilla', 'fix', 'branding'),
#  ('opens', 'mozilla', 'fix', 'branding', 'auto'),
#  ('mozilla', 'fix', 'branding', 'auto', 'close'),
#  ('fix', 'branding', 'auto', 'close', 'for'),
#  ('branding', 'auto', 'close', 'for', 'download'),
#  ('auto', 'close', 'for', 'download', 'manager'),
#  ('close', 'for', 'download', 'manager', 'would'),
#  ('for', 'download', 'manager', 'would', 'be'),
#  ('download', 'manager', 'would', 'be', 'nice'),
#  ('manager', 'would', 'be', 'nice', 'Components'),
#  ('would', 'be', 'nice', 'Components', 'of'),
#  ('be', 'nice', 'Components', 'of', 'the'),
#  ('nice', 'Components', 'of', 'the', 'Navigation'),
#  ('Components', 'of', 'the', 'Navigation', 'Toolbar'),
#  ('of', 'the', 'Navigation', 'Toolbar', 'do'),
#  ('the', 'Navigation', 'Toolbar', 'do', 'not'),
#  ('Navigation', 'Toolbar', 'do', 'not', 'appear'),
#  ('Toolbar', 'do', 'not', 'appear', 'with'),
#  ('do', 'not', 'appear', 'with', 'the'),
#  ('not', 'appear', 'with', 'the', 'Modern'),
#  ('appear', 'with', 'the', 'Modern', 'theme'),
#  ('with', 'the', 'Modern', 'theme', '.'),
#  ('the', 'Modern', 'theme', '.', 'Pop'),
#  ('Modern', 'theme', '.', 'Pop', 'up'),
#  ('theme', '.', 'Pop', 'up', 'window'),
#  ('.', 'Pop', 'up', 'window', 'blocking'),
#  ('Pop', 'up', 'window', 'blocking', 'Uabar'),
#  ('up', 'window', 'blocking', 'Uabar', 'doesn'),
#  ('window', 'blocking', 'Uabar', 'doesn', "'"),
#  ('blocking', 'Uabar', 'doesn', "'", 't'),
#  ('Uabar', 'doesn', "'", 't', 'work'),
#  ('doesn', "'", 't', 'work', 'Theme'),
#  ("'", 't', 'work', 'Theme', 'changes'),
#  ('t', 'work', 'Theme', 'changes', 'will'),
#  ('work', 'Theme', 'changes', 'will', 'take'),
#  ('Theme', 'changes', 'will', 'take', 'effect'),
#  ('changes', 'will', 'take', 'effect', 'when'),
#  ('will', 'take', 'effect', 'when', 'you'),
#  ('take', 'effect', 'when', 'you', 'restart'),
#  ('effect', 'when', 'you', 'restart', '_Mozilla_'),
#  ('when', 'you', 'restart', '_Mozilla_', '.'),
#  ('you', 'restart', '_Mozilla_', '.', 'Need'),
#  ('restart', '_Mozilla_', '.', 'Need', 'large'),
#  ('_Mozilla_', '.', 'Need', 'large', 'icons'),
#  ('.', 'Need', 'large', 'icons', 'for'),
#  ('Need', 'large', 'icons', 'for', 'the'),
#  ('large', 'icons', 'for', 'the', 'Options'),
#  ('icons', 'for', 'the', 'Options', 'menu'),
#  ('for', 'the', 'Options', 'menu', 'Enable'),
#  ('the', 'Options', 'menu', 'Enable', 'images'),
#  ('Options', 'menu', 'Enable', 'images', 'cannot'),
#  ('menu', 'Enable', 'images', 'cannot', 'be'),
#  ('Enable', 'images', 'cannot', 'be', 'used'),
#  ('images', 'cannot', 'be', 'used', 'to'),
#  ('cannot', 'be', 'used', 'to', 'disable'),
#  ('be', 'used', 'to', 'disable', 'the'),
#  ('used', 'to', 'disable', 'the', 'display'),
#  ('to', 'disable', 'the', 'display', 'of'),
#  ('disable', 'the', 'display', 'of', 'images'),
#  ('the', 'display', 'of', 'images', '.'),
#  ('display', 'of', 'images', '.', 'The'),
#  ('of', 'images', '.', 'The', 'bookmark'),
#  ('images', '.', 'The', 'bookmark', 'tree'),
#  ('.', 'The', 'bookmark', 'tree', 'jumps'),
#  ('The', 'bookmark', 'tree', 'jumps', 'unexpectedly'),
#  ('bookmark', 'tree', 'jumps', 'unexpectedly', 'to'),
#  ('tree', 'jumps', 'unexpectedly', 'to', 'the'),
#  ('jumps', 'unexpectedly', 'to', 'the', 'bottom'),
#  ('unexpectedly', 'to', 'the', 'bottom', 'of'),
#  ('to', 'the', 'bottom', 'of', 'its'),
#  ('the', 'bottom', 'of', 'its', 'view'),
#  ('bottom', 'of', 'its', 'view', 'when'),
#  ('of', 'its', 'view', 'when', 'the'),
#  ('its', 'view', 'when', 'the', 'the'),
#  ('view', 'when', 'the', 'the', 'first'),
#  ('when', 'the', 'the', 'first', 'visible'),
#  ('the', 'the', 'first', 'visible', 'row'),
#  ('the', 'first', 'visible', 'row', 'is'),
#  ('first', 'visible', 'row', 'is', 'not'),
#  ('visible', 'row', 'is', 'not', 'the'),
#  ('row', 'is', 'not', 'the', 'first'),
#  ('is', 'not', 'the', 'first', 'one'),
#  ('not', 'the', 'first', 'one', 'Move'),
#  ('the', 'first', 'one', 'Move', 'bookmarks'),
#  ('first', 'one', 'Move', 'bookmarks', 'transactions'),
#  ('one', 'Move', 'bookmarks', 'transactions', 'into'),
#  ('Move', 'bookmarks', 'transactions', 'into', 'a'),
#  ('bookmarks', 'transactions', 'into', 'a', 'JS'),
#  ('transactions', 'into', 'a', 'JS', 'service'),
#  ('into', 'a', 'JS', 'service', '('),
#  ('a', 'JS', 'service', '(', 'adding'),
#  ('JS', 'service', '(', 'adding', 'a'),
#  ('service', '(', 'adding', 'a', 'bookmark'),
#  ('(', 'adding', 'a', 'bookmark', 'leaks'),
#  ('adding', 'a', 'bookmark', 'leaks', 'the'),
#  ('a', 'bookmark', 'leaks', 'the', 'Add'),
#  ('bookmark', 'leaks', 'the', 'Add', 'Bookmark'),
#  ('leaks', 'the', 'Add', 'Bookmark', 'dialog'),
#  ('the', 'Add', 'Bookmark', 'dialog', ')'),
#  ('Add', 'Bookmark', 'dialog', ')', 'Shortcut'),
#  ('Bookmark', 'dialog', ')', 'Shortcut', 'Ctrl'),
#  ('dialog', ')', 'Shortcut', 'Ctrl', '-'),
#  (')', 'Shortcut', 'Ctrl', '-', 'Y'),
#  ('Shortcut', 'Ctrl', '-', 'Y', '('),
#  ('Ctrl', '-', 'Y', '(', 'redo'),
#  ('-', 'Y', '(', 'redo', ')'),
#  ('Y', '(', 'redo', ')', 'does'),
#  ('(', 'redo', ')', 'does', 'not'),
#  ('redo', ')', 'does', 'not', 'work'),
#  (')', 'does', 'not', 'work', 'in'),
#  ('does', 'not', 'work', 'in', 'Bookmarks'),
#  ('not', 'work', 'in', 'Bookmarks', 'Manager'),
#  ('work', 'in', 'Bookmarks', 'Manager', 'Eradicate'),
#  ('in', 'Bookmarks', 'Manager', 'Eradicate', 'AddBookmarkImmediately'),
#  ('Bookmarks', 'Manager', 'Eradicate', 'AddBookmarkImmediately', 'Deleting'),
#  ('Manager', 'Eradicate', 'AddBookmarkImmediately', 'Deleting', 'a'),
#  ('Eradicate', 'AddBookmarkImmediately', 'Deleting', 'a', 'selection'),
#  ('AddBookmarkImmediately', 'Deleting', 'a', 'selection', 'should'),
#  ('Deleting', 'a', 'selection', 'should', 'select'),
#  ('a', 'selection', 'should', 'select', 'the'),
#  ('selection', 'should', 'select', 'the', 'next'),
#  ('should', 'select', 'the', 'next', 'item'),
#  ('select', 'the', 'next', 'item', 'transaction'),
#  ('the', 'next', 'item', 'transaction', 'manager'),
#  ('next', 'item', 'transaction', 'manager', 'does'),
#  ('item', 'transaction', 'manager', 'does', 'not'),
#  ('transaction', 'manager', 'does', 'not', 'handle'),
#  ('manager', 'does', 'not', 'handle', 'import'),
#  ('does', 'not', 'handle', 'import', 'customize'),
#  ('not', 'handle', 'import', 'customize', 'toolbar'),
#  ('handle', 'import', 'customize', 'toolbar', 'clears'),
#  ('import', 'customize', 'toolbar', 'clears', 'URL'),
#  ('customize', 'toolbar', 'clears', 'URL', '3'),
#  ('toolbar', 'clears', 'URL', '3', '.'),
#  ('clears', 'URL', '3', '.', '2'),
#  ('URL', '3', '.', '2', '%'),
#  ('3', '.', '2', '%', 'increase'),
#  ('.', '2', '%', 'increase', 'in'),
#  ('2', '%', 'increase', 'in', 'Phoenix'),
#  ('%', 'increase', 'in', 'Phoenix', 'Ts'),
#  ('increase', 'in', 'Phoenix', 'Ts', 'after'),
#  ('in', 'Phoenix', 'Ts', 'after', 'bookmark'),
#  ('Phoenix', 'Ts', 'after', 'bookmark', 'landing'),
#  ('Ts', 'after', 'bookmark', 'landing', 'cannot'),
#  ('after', 'bookmark', 'landing', 'cannot', 'close'),
#  ('bookmark', 'landing', 'cannot', 'close', 'folder'),
#  ('landing', 'cannot', 'close', 'folder', 'with'),
#  ('cannot', 'close', 'folder', 'with', 'single'),
#  ('close', 'folder', 'with', 'single', 'click'),
#  ('folder', 'with', 'single', 'click', 'on'),
#  ('with', 'single', 'click', 'on', 'twistie'),
#  ('single', 'click', 'on', 'twistie', 'Pref'),
#  ('click', 'on', 'twistie', 'Pref', 'UI'),
#  ('on', 'twistie', 'Pref', 'UI', 'to'),
#  ('twistie', 'Pref', 'UI', 'to', 'specify'),
#  ('Pref', 'UI', 'to', 'specify', 'a'),
#  ('UI', 'to', 'specify', 'a', 'proxy'),
#  ('to', 'specify', 'a', 'proxy', 'server'),
#  ('specify', 'a', 'proxy', 'server', 'for'),
#  ('a', 'proxy', 'server', 'for', 'web'),
#  ('proxy', 'server', 'for', 'web', 'navigation'),
#  ('server', 'for', 'web', 'navigation', 'Implement'),
#  ('for', 'web', 'navigation', 'Implement', 'improved'),
#  ('web', 'navigation', 'Implement', 'improved', 'Implement'),
#  ('navigation', 'Implement', 'improved', 'Implement', 'global'),
#  ('Implement', 'improved', 'Implement', 'global', 'Go'),
#  ('improved', 'Implement', 'global', 'Go', 'menu'),
#  ('Implement', 'global', 'Go', 'menu', 'Readd'),
#  ('global', 'Go', 'menu', 'Readd', 'Open'),
#  ('Go', 'menu', 'Readd', 'Open', 'Location'),
#  ('menu', 'Readd', 'Open', 'Location', 'Need'),
#  ('Readd', 'Open', 'Location', 'Need', 'tab'),
#  ('Open', 'Location', 'Need', 'tab', 'loading'),
#  ('Location', 'Need', 'tab', 'loading', 'icon'),
#  ('Need', 'tab', 'loading', 'icon', 'first'),
#  ('tab', 'loading', 'icon', 'first', 'Mozilla'),
#  ('loading', 'icon', 'first', 'Mozilla', 'Firefox'),
#  ('icon', 'first', 'Mozilla', 'Firefox', 'window'),
#  ('first', 'Mozilla', 'Firefox', 'window', 'ignored'),
#  ('Mozilla', 'Firefox', 'window', 'ignored', 'by'),
#  ('Firefox', 'window', 'ignored', 'by', 'nsIWindowMediator'),
#  ('window', 'ignored', 'by', 'nsIWindowMediator', 'first'),
#  ('ignored', 'by', 'nsIWindowMediator', 'first', 'Phoenix'),
#  ('by', 'nsIWindowMediator', 'first', 'Phoenix', 'window'),
#  ('nsIWindowMediator', 'first', 'Phoenix', 'window', 'ignored'),
#  ('first', 'Phoenix', 'window', 'ignored', 'by'),
#  ('Phoenix', 'window', 'ignored', 'by', 'nsIWindowMediator'),
#  ('window', 'ignored', 'by', 'nsIWindowMediator', 'preferences'),
#  ('ignored', 'by', 'nsIWindowMediator', 'preferences', 'no'),
#  ('by', 'nsIWindowMediator', 'preferences', 'no', 'longer'),
#  ('nsIWindowMediator', 'preferences', 'no', 'longer', 'works'),
#  ('preferences', 'no', 'longer', 'works', 'Open'),
#  ('no', 'longer', 'works', 'Open', 'Personal'),
#  ('longer', 'works', 'Open', 'Personal', 'Toolbar'),
#  ('works', 'Open', 'Personal', 'Toolbar', 'folder'),
#  ('Open', 'Personal', 'Toolbar', 'folder', 'in'),
#  ('Personal', 'Toolbar', 'folder', 'in', 'toolbar'),
#  ('Toolbar', 'folder', 'in', 'toolbar', 'web'),
#  ('folder', 'in', 'toolbar', 'web', 'search'),
#  ('in', 'toolbar', 'web', 'search', 'for'),
#  ('toolbar', 'web', 'search', 'for', '""'),
#  ('web', 'search', 'for', '""', 'in'),
#  ('search', 'for', '""', 'in', 'context'),
#  ('for', '""', 'in', 'context', 'menu'),
#  ('""', 'in', 'context', 'menu', 'don'),
#  ('in', 'context', 'menu', 'don', "'"),
#  ('context', 'menu', 'don', "'", 't'),
#  ('menu', 'don', "'", 't', 'work'),
#  ('don', "'", 't', 'work', 'Fix'),
#  ("'", 't', 'work', 'Fix', 'full'),
#  ('t', 'work', 'Fix', 'full', 'screen'),
#  ('work', 'Fix', 'full', 'screen', 'to'),
#  ('Fix', 'full', 'screen', 'to', 'have'),
#  ('full', 'screen', 'to', 'have', 'smaller'),
#  ('screen', 'to', 'have', 'smaller', 'icons'),
#  ('to', 'have', 'smaller', 'icons', 'Port'),
#  ('have', 'smaller', 'icons', 'Port', 'patch'),
#  ('smaller', 'icons', 'Port', 'patch', 'to'),
#  ('icons', 'Port', 'patch', 'to', 'bug'),
#  ('Port', 'patch', 'to', 'bug', '164006'),
#  ('patch', 'to', 'bug', '164006', '('),
#  ('to', 'bug', '164006', '(', 'wyciwyg'),
#  ('bug', '164006', '(', 'wyciwyg', ':'),
#  ('164006', '(', 'wyciwyg', ':', 'in'),
#  ('(', 'wyciwyg', ':', 'in', 'tab'),
#  ('wyciwyg', ':', 'in', 'tab', 'titles'),
#  (':', 'in', 'tab', 'titles', ')'),
#  ('in', 'tab', 'titles', ')', '['),
#  ('tab', 'titles', ')', '[', 'cust'),
#  ('titles', ')', '[', 'cust', ']'),
#  (')', '[', 'cust', ']', 'Add'),
#  ('[', 'cust', ']', 'Add', 'more'),
#  ('cust', ']', 'Add', 'more', 'off'),
#  (']', 'Add', 'more', 'off', '-'),
#  ('Add', 'more', 'off', '-', 'by'),
#  ('more', 'off', '-', 'by', '-'),
#  ('off', '-', 'by', '-', 'default'),
#  ('-', 'by', '-', 'default', 'toolbar'),
#  ('by', '-', 'default', 'toolbar', 'buttons'),
#  ('-', 'default', 'toolbar', 'buttons', 'textmode'),
#  ('default', 'toolbar', 'buttons', 'textmode', 'buttons'),
#  ('toolbar', 'buttons', 'textmode', 'buttons', 'need'),
#  ('buttons', 'textmode', 'buttons', 'need', 'hover'),
#  ('textmode', 'buttons', 'need', 'hover', 'state'),
#  ('buttons', 'need', 'hover', 'state', 'enable'),
#  ('need', 'hover', 'state', 'enable', 'nsITheme'),
#  ('hover', 'state', 'enable', 'nsITheme', 'form'),
#  ('state', 'enable', 'nsITheme', 'form', 'control'),
#  ('enable', 'nsITheme', 'form', 'control', 'goodness'),
#  ('nsITheme', 'form', 'control', 'goodness', 'for'),
#  ('form', 'control', 'goodness', 'for', 'Phoenix'),
#  ('control', 'goodness', 'for', 'Phoenix', 'rename'),
#  ('goodness', 'for', 'Phoenix', 'rename', 'executable'),
#  ('for', 'Phoenix', 'rename', 'executable', 'and'),
#  ('Phoenix', 'rename', 'executable', 'and', 'profile'),
#  ('rename', 'executable', 'and', 'profile', 'dir'),
#  ('executable', 'and', 'profile', 'dir', 'Need'),
#  ('and', 'profile', 'dir', 'Need', 'to'),
#  ('profile', 'dir', 'Need', 'to', 'enable'),
#  ('dir', 'Need', 'to', 'enable', 'wallet'),
#  ('Need', 'to', 'enable', 'wallet', '('),
#  ('to', 'enable', 'wallet', '(', 'password'),
#  ('enable', 'wallet', '(', 'password', 'manager'),
#  ('wallet', '(', 'password', 'manager', 'manager'),
#  ('(', 'password', 'manager', 'manager', 'manager'),
#  ('password', 'manager', 'manager', 'manager', ')'),
#  ('manager', 'manager', 'manager', ')', 'New'),
#  ('manager', 'manager', ')', 'New', 'Extension'),
#  ('manager', ')', 'New', 'Extension', 'Manager'),
#  (')', 'New', 'Extension', 'Manager', 'the'),
#  ('New', 'Extension', 'Manager', 'the', 'changes'),
#  ('Extension', 'Manager', 'the', 'changes', 'to'),
#  ('Manager', 'the', 'changes', 'to', 'mozbrowser'),
#  ('the', 'changes', 'to', 'mozbrowser', 'too'),
#  ('changes', 'to', 'mozbrowser', 'too', 'confusing'),
#  ('to', 'mozbrowser', 'too', 'confusing', 'and'),
#  ('mozbrowser', 'too', 'confusing', 'and', 'too'),
#  ('too', 'confusing', 'and', 'too', 'much'),
#  ('confusing', 'and', 'too', 'much', 'Missing'),
#  ('and', 'too', 'much', 'Missing', 'proxy'),
#  ('too', 'much', 'Missing', 'proxy', 'image'),
#  ('much', 'Missing', 'proxy', 'image', 'Cannot'),
#  ('Missing', 'proxy', 'image', 'Cannot', 'File'),
#  ('proxy', 'image', 'Cannot', 'File', '>'),
#  ('image', 'Cannot', 'File', '>', 'New'),
#  ('Cannot', 'File', '>', 'New', 'Bookmark'),
#  ('File', '>', 'New', 'Bookmark', 'while'),
#  ('>', 'New', 'Bookmark', 'while', 'managing'),
#  ('New', 'Bookmark', 'while', 'managing', 'a'),
#  ('Bookmark', 'while', 'managing', 'a', 'new'),
#  ('while', 'managing', 'a', 'new', 'folder'),
#  ('managing', 'a', 'new', 'folder', 'Bookmarks'),
#  ('a', 'new', 'folder', 'Bookmarks', 'are'),
#  ('new', 'folder', 'Bookmarks', 'are', 'not'),
#  ('folder', 'Bookmarks', 'are', 'not', 'loaded'),
#  ('Bookmarks', 'are', 'not', 'loaded', 'if'),
#  ('are', 'not', 'loaded', 'if', 'the'),
#  ('not', 'loaded', 'if', 'the', 'Personal'),
#  ('loaded', 'if', 'the', 'Personal', 'Toolbar'),
#  ('if', 'the', 'Personal', 'Toolbar', 'is'),
#  ('the', 'Personal', 'Toolbar', 'is', 'switched'),
#  ('Personal', 'Toolbar', 'is', 'switched', 'off'),
#  ('Toolbar', 'is', 'switched', 'off', 'Pretty'),
#  ('is', 'switched', 'off', 'Pretty', 'up'),
#  ('switched', 'off', 'Pretty', 'up', 'dns'),
#  ('off', 'Pretty', 'up', 'dns', 'error'),
#  ('Pretty', 'up', 'dns', 'error', 'page'),
#  ('up', 'dns', 'error', 'page', 'a'),
#  ('dns', 'error', 'page', 'a', 'bit'),
#  ('error', 'page', 'a', 'bit', 'middle'),
#  ('page', 'a', 'bit', 'middle', 'click'),
#  ('a', 'bit', 'middle', 'click', '('),
#  ('bit', 'middle', 'click', '(', 'pt'),
#  ('middle', 'click', '(', 'pt', '+'),
#  ('click', '(', 'pt', '+', 'bookmark'),
#  ('(', 'pt', '+', 'bookmark', 'menu'),
#  ('pt', '+', 'bookmark', 'menu', ')'),
#  ('+', 'bookmark', 'menu', ')', 'loads'),
#  ('bookmark', 'menu', ')', 'loads', 'in'),
#  ('menu', ')', 'loads', 'in', 'the'),
#  (')', 'loads', 'in', 'the', 'current'),
#  ('loads', 'in', 'the', 'current', 'tab'),
#  ('in', 'the', 'current', 'tab', '+'),
#  ('the', 'current', 'tab', '+', 'new'),
#  ('current', 'tab', '+', 'new', 'tab'),
#  ('tab', '+', 'new', 'tab', 'Nightly'),
#  ('+', 'new', 'tab', 'Nightly', 'for'),
#  ('new', 'tab', 'Nightly', 'for', '22'),
#  ('tab', 'Nightly', 'for', '22', 'Sept'),
#  ('Nightly', 'for', '22', 'Sept', 'displays'),
#  ('for', '22', 'Sept', 'displays', 'page'),
#  ('22', 'Sept', 'displays', 'page', 'details'),
#  ('Sept', 'displays', 'page', 'details', 'above'),
#  ('displays', 'page', 'details', 'above', 'window'),
#  ('page', 'details', 'above', 'window', 'Ctrl'),
#  ('details', 'above', 'window', 'Ctrl', '-'),
#  ('above', 'window', 'Ctrl', '-', 'W'),
#  ('window', 'Ctrl', '-', 'W', 'does'),
#  ('Ctrl', '-', 'W', 'does', 'not'),
#  ('-', 'W', 'does', 'not', 'close'),
#  ('W', 'does', 'not', 'close', 'the'),
#  ('does', 'not', 'close', 'the', 'current'),
#  ('not', 'close', 'the', 'current', 'tab'),
#  ('close', 'the', 'current', 'tab', 'listboxes'),
#  ('the', 'current', 'tab', 'listboxes', 'and'),
#  ('current', 'tab', 'listboxes', 'and', 'tree'),
#  ('tab', 'listboxes', 'and', 'tree', 'views'),
#  ('listboxes', 'and', 'tree', 'views', 'don'),
#  ('and', 'tree', 'views', 'don', "'"),
#  ('tree', 'views', 'don', "'", 't'),
#  ('views', 'don', "'", 't', 'support'),
#  ('don', "'", 't', 'support', 'themes'),
#  ("'", 't', 'support', 'themes', 'on'),
#  ('t', 'support', 'themes', 'on', 'winxp'),
#  ('support', 'themes', 'on', 'winxp', 'Ctrl'),
#  ('themes', 'on', 'winxp', 'Ctrl', '+'),
#  ('on', 'winxp', 'Ctrl', '+', 'Mousewheel'),
#  ('winxp', 'Ctrl', '+', 'Mousewheel', 'should'),
#  ('Ctrl', '+', 'Mousewheel', 'should', 'resize'),
#  ('+', 'Mousewheel', 'should', 'resize', 'text'),
#  ('Mousewheel', 'should', 'resize', 'text', 'bookmarks'),
#  ('should', 'resize', 'text', 'bookmarks', 'should'),
#  ('resize', 'text', 'bookmarks', 'should', 'import'),
#  ('text', 'bookmarks', 'should', 'import', 'Mozilla'),
#  ('bookmarks', 'should', 'import', 'Mozilla', "'"),
#  ('should', 'import', 'Mozilla', "'", 's'),
#  ('import', 'Mozilla', "'", 's', 'bookmarks'),
#  ('Mozilla', "'", 's', 'bookmarks', 'Please'),
#  ("'", 's', 'bookmarks', 'Please', 'tell'),
#  ('s', 'bookmarks', 'Please', 'tell', 'people'),
#  ('bookmarks', 'Please', 'tell', 'people', 'to'),
#  ('Please', 'tell', 'people', 'to', 'use'),
#  ('tell', 'people', 'to', 'use', 'a'),
#  ('people', 'to', 'use', 'a', 'new'),
#  ('to', 'use', 'a', 'new', 'profile'),
#  ('use', 'a', 'new', 'profile', '.'),
#  ('a', 'new', 'profile', '.', 'combine'),
#  ('new', 'profile', '.', 'combine', 'links'),
#  ('profile', '.', 'combine', 'links', '+'),
#  ('.', 'combine', 'links', '+', 'toolbar'),
#  ('combine', 'links', '+', 'toolbar', 'File'),
#  ('links', '+', 'toolbar', 'File', '|'),
#  ('+', 'toolbar', 'File', '|', 'Import'),
#  ('toolbar', 'File', '|', 'Import', '...'),
#  ('File', '|', 'Import', '...', 'does'),
#  ('|', 'Import', '...', 'does', 'not'),
#  ('Import', '...', 'does', 'not', 'work'),
#  ('...', 'does', 'not', 'work', 'cannot'),
#  ('does', 'not', 'work', 'cannot', 'import'),
#  ('not', 'work', 'cannot', 'import', '4'),
#  ('work', 'cannot', 'import', '4', '.'),
#  ('cannot', 'import', '4', '.', 'x'),
#  ('import', '4', '.', 'x', 'About'),
#  ('4', '.', 'x', 'About', 'dialog'),
#  ('.', 'x', 'About', 'dialog', 'weirdness'),
#  ('x', 'About', 'dialog', 'weirdness', 'Context'),
#  ('About', 'dialog', 'weirdness', 'Context', 'menu'),
#  ('dialog', 'weirdness', 'Context', 'menu', 'doesn'),
#  ('weirdness', 'Context', 'menu', 'doesn', "'"),
#  ('Context', 'menu', 'doesn', "'", 't'),
#  ('menu', 'doesn', "'", 't', 'appear'),
#  ('doesn', "'", 't', 'appear', 'when'),
#  ("'", 't', 'appear', 'when', 'right'),
#  ('t', 'appear', 'when', 'right', 'clicking'),
#  ('appear', 'when', 'right', 'clicking', 'on'),
#  ('when', 'right', 'clicking', 'on', 'disabled'),
#  ('right', 'clicking', 'on', 'disabled', 'forward'),
#  ('clicking', 'on', 'disabled', 'forward', 'or'),
#  ('on', 'disabled', 'forward', 'or', 'back'),
#  ('disabled', 'forward', 'or', 'back', 'can'),
#  ('forward', 'or', 'back', 'can', "'"),
#  ('or', 'back', 'can', "'", 't'),
#  ('back', 'can', "'", 't', 'specify'),
#  ('can', "'", 't', 'specify', 'cookie'),
#  ("'", 't', 'specify', 'cookie', 'details'),
#  ('t', 'specify', 'cookie', 'details', 'Proxy'),
#  ('specify', 'cookie', 'details', 'Proxy', 'settings'),
#  ('cookie', 'details', 'Proxy', 'settings', 'in'),
#  ('details', 'Proxy', 'settings', 'in', 'prefs'),
#  ('Proxy', 'settings', 'in', 'prefs', '.'),
#  ('settings', 'in', 'prefs', '.', 'js'),
#  ('in', 'prefs', '.', 'js', 'seem'),
#  ('prefs', '.', 'js', 'seem', 'to'),
#  ('.', 'js', 'seem', 'to', 'be'),
#  ('js', 'seem', 'to', 'be', 'ignored'),
#  ('seem', 'to', 'be', 'ignored', '...'),
#  ('to', 'be', 'ignored', '...', 'Incorrectly'),
#  ('be', 'ignored', '...', 'Incorrectly', 'renders'),
#  ('ignored', '...', 'Incorrectly', 'renders', 'various'),
#  ('...', 'Incorrectly', 'renders', 'various', 'web'),
#  ('Incorrectly', 'renders', 'various', 'web', 'pages'),
#  ('renders', 'various', 'web', 'pages', 'Window'),
#  ('various', 'web', 'pages', 'Window', 'won'),
#  ('web', 'pages', 'Window', 'won', "'"),
#  ('pages', 'Window', 'won', "'", 't'),
#  ('Window', 'won', "'", 't', 'show'),
#  ('won', "'", 't', 'show', 'completely'),
#  ("'", 't', 'show', 'completely', 'Can'),
#  ('t', 'show', 'completely', 'Can', "'"),
#  ('show', 'completely', 'Can', "'", 't'),
#  ('completely', 'Can', "'", 't', 'change'),
#  ('Can', "'", 't', 'change', 'privacy'),
#  ("'", 't', 'change', 'privacy', 'settings'),
#  ('t', 'change', 'privacy', 'settings', '['),
#  ('change', 'privacy', 'settings', '[', 'Moz'),
#  ('privacy', 'settings', '[', 'Moz', ']'),
#  ('settings', '[', 'Moz', ']', 'Cannot'),
#  ('[', 'Moz', ']', 'Cannot', 'set'),
#  ('Moz', ']', 'Cannot', 'set', '"'),
#  (']', 'Cannot', 'set', '"', 'Imported'),
#  ('Cannot', 'set', '"', 'Imported', 'IE'),
#  ('set', '"', 'Imported', 'IE', 'Favorites'),
#  ('"', 'Imported', 'IE', 'Favorites', '"'),
#  ('Imported', 'IE', 'Favorites', '"', 'to'),
#  ('IE', 'Favorites', '"', 'to', 'default'),
#  ('Favorites', '"', 'to', 'default', 'personal'),
#  ('"', 'to', 'default', 'personal', 'toolbar'),
#  ('to', 'default', 'personal', 'toolbar', 'folder'),
#  ('default', 'personal', 'toolbar', 'folder', 'pheonix'),
#  ('personal', 'toolbar', 'folder', 'pheonix', 'Need'),
#  ('toolbar', 'folder', 'pheonix', 'Need', 'smaller'),
#  ('folder', 'pheonix', 'Need', 'smaller', 'throbber'),
#  ('pheonix', 'Need', 'smaller', 'throbber', 'to'),
#  ('Need', 'smaller', 'throbber', 'to', 'use'),
#  ('smaller', 'throbber', 'to', 'use', 'with'),
#  ('throbber', 'to', 'use', 'with', 'small'),
#  ('to', 'use', 'with', 'small', 'icons'),
#  ('use', 'with', 'small', 'icons', 'Blank'),
#  ('with', 'small', 'icons', 'Blank', 'URL'),
#  ('small', 'icons', 'Blank', 'URL', 'bar'),
#  ('icons', 'Blank', 'URL', 'bar', 'after'),
#  ('Blank', 'URL', 'bar', 'after', 'using'),
#  ('URL', 'bar', 'after', 'using', 'Customize'),
#  ('bar', 'after', 'using', 'Customize', 'Toolbar'),
#  ('after', 'using', 'Customize', 'Toolbar', 'Mousewheel'),
#  ('using', 'Customize', 'Toolbar', 'Mousewheel', 'does'),
#  ('Customize', 'Toolbar', 'Mousewheel', 'does', 'not'),
#  ('Toolbar', 'Mousewheel', 'does', 'not', 'scroll'),
#  ('Mousewheel', 'does', 'not', 'scroll', 'web'),
#  ('does', 'not', 'scroll', 'web', 'page'),
#  ('not', 'scroll', 'web', 'page', 'ctrl'),
#  ('scroll', 'web', 'page', 'ctrl', '+'),
#  ('web', 'page', 'ctrl', '+', 'tab'),
#  ('page', 'ctrl', '+', 'tab', 'should'),
#  ('ctrl', '+', 'tab', 'should', 'switch'),
#  ('+', 'tab', 'should', 'switch', 'tabs'),
#  ('tab', 'should', 'switch', 'tabs', 'in'),
#  ('should', 'switch', 'tabs', 'in', 'browser'),
#  ('switch', 'tabs', 'in', 'browser', 'favicon'),
#  ('tabs', 'in', 'browser', 'favicon', '.'),
#  ('in', 'browser', 'favicon', '.', 'ico'),
#  ('browser', 'favicon', '.', 'ico', 'colors'),
#  ('favicon', '.', 'ico', 'colors', 'render'),
#  ('.', 'ico', 'colors', 'render', 'improperly'),
#  ('ico', 'colors', 'render', 'improperly', 'in'),
#  ('colors', 'render', 'improperly', 'in', 'tabs'),
#  ('render', 'improperly', 'in', 'tabs', 'and'),
#  ('improperly', 'in', 'tabs', 'and', 'URL'),
#  ('in', 'tabs', 'and', 'URL', 'bar'),
#  ('tabs', 'and', 'URL', 'bar', '-'),
#  ('and', 'URL', 'bar', '-', 'remote'),
#  ('URL', 'bar', '-', 'remote', 'openurl'),
#  ('bar', '-', 'remote', 'openurl', '()'),
#  ('-', 'remote', 'openurl', '()', 'opens'),
#  ('remote', 'openurl', '()', 'opens', 'Mozilla'),
#  ('openurl', '()', 'opens', 'Mozilla', 'window'),
#  ('()', 'opens', 'Mozilla', 'window', 'if'),
#  ('opens', 'Mozilla', 'window', 'if', 'Mozilla'),
#  ('Mozilla', 'window', 'if', 'Mozilla', 'is'),
#  ('window', 'if', 'Mozilla', 'is', 'running'),
#  ('if', 'Mozilla', 'is', 'running', 'make'),
#  ('Mozilla', 'is', 'running', 'make', 'preferences'),
#  ('is', 'running', 'make', 'preferences', 'resizable'),
#  ('running', 'make', 'preferences', 'resizable', 'Scroll'),
#  ('make', 'preferences', 'resizable', 'Scroll', 'bar'),
#  ('preferences', 'resizable', 'Scroll', 'bar', 'becomes'),
#  ('resizable', 'Scroll', 'bar', 'becomes', 'blank'),
#  ('Scroll', 'bar', 'becomes', 'blank', 'fix'),
#  ('bar', 'becomes', 'blank', 'fix', 'addressbar'),
#  ('becomes', 'blank', 'fix', 'addressbar', 'dropdown'),
#  ('blank', 'fix', 'addressbar', 'dropdown', 'icon'),
#  ('fix', 'addressbar', 'dropdown', 'icon', 'for'),
#  ('addressbar', 'dropdown', 'icon', 'for', 'linux'),
#  ('dropdown', 'icon', 'for', 'linux', '.'),
#  ('icon', 'for', 'linux', '.', '"'),
#  ('for', 'linux', '.', '"', 'Find'),
#  ('linux', '.', '"', 'Find', 'Next'),
#  ('.', '"', 'Find', 'Next', '"'),
#  ('"', 'Find', 'Next', '"', 'button'),
#  ('Find', 'Next', '"', 'button', 'doesn'),
#  ('Next', '"', 'button', 'doesn', "'"),
#  ('"', 'button', 'doesn', "'", 't'),
#  ('button', 'doesn', "'", 't', 'always'),
#  ('doesn', "'", 't', 'always', 'respond'),
#  ("'", 't', 'always', 'respond', 'to'),
#  ('t', 'always', 'respond', 'to', 'Enter'),
#  ('always', 'respond', 'to', 'Enter', 'Ctrl'),
#  ('respond', 'to', 'Enter', 'Ctrl', '+'),
#  ('to', 'Enter', 'Ctrl', '+', 'Mousewheel'),
#  ('Enter', 'Ctrl', '+', 'Mousewheel', 'should'),
#  ('Ctrl', '+', 'Mousewheel', 'should', 'cycle'),
#  ('+', 'Mousewheel', 'should', 'cycle', 'tabs'),
#  ('Mousewheel', 'should', 'cycle', 'tabs', 'A'),
#  ('should', 'cycle', 'tabs', 'A', 'new'),
#  ('cycle', 'tabs', 'A', 'new', 'icon'),
#  ('tabs', 'A', 'new', 'icon', 'for'),
#  ('A', 'new', 'icon', 'for', 'Firebird'),
#  ('new', 'icon', 'for', 'Firebird', '2nd'),
#  ('icon', 'for', 'Firebird', '2nd', 'Copy'),
#  ('for', 'Firebird', '2nd', 'Copy', 'won'),
#  ('Firebird', '2nd', 'Copy', 'won', "'"),
#  ('2nd', 'Copy', 'won', "'", 't'),
#  ('Copy', 'won', "'", 't', 'load'),
#  ('won', "'", 't', 'load', 'with'),
#  ("'", 't', 'load', 'with', 'same'),
#  ('t', 'load', 'with', 'same', 'profile'),
#  ('load', 'with', 'same', 'profile', 'width'),
#  ('with', 'same', 'profile', 'width', 'of'),
#  ('same', 'profile', 'width', 'of', 'table'),
#  ('profile', 'width', 'of', 'table', 'containing'),
#  ('width', 'of', 'table', 'containing', 'text'),
#  ('of', 'table', 'containing', 'text', 'being'),
#  ('table', 'containing', 'text', 'being', 'handled'),
#  ('containing', 'text', 'being', 'handled', 'incorrectly'),
#  ('text', 'being', 'handled', 'incorrectly', '('),
#  ('being', 'handled', 'incorrectly', '(', 'multiple'),
#  ('handled', 'incorrectly', '(', 'multiple', 'screenwidths'),
#  ('incorrectly', '(', 'multiple', 'screenwidths', 'wide'),
#  ('(', 'multiple', 'screenwidths', 'wide', ')'),
#  ('multiple', 'screenwidths', 'wide', ')', 'accessing'),
#  ('screenwidths', 'wide', ')', 'accessing', '"'),
#  ('wide', ')', 'accessing', '"', 'navigator'),
#  (')', 'accessing', '"', 'navigator', '.'),
#  ('accessing', '"', 'navigator', '.', 'cookieEnabled'),
#  ('"', 'navigator', '.', 'cookieEnabled', '"'),
#  ('navigator', '.', 'cookieEnabled', '"', 'produces'),
#  ('.', 'cookieEnabled', '"', 'produces', '"'),
#  ('cookieEnabled', '"', 'produces', '"', 'uncaught'),
#  ('"', 'produces', '"', 'uncaught', 'exception'),
#  ('produces', '"', 'uncaught', 'exception', '"'),
#  ('"', 'uncaught', 'exception', '"', 'Need'),
#  ('uncaught', 'exception', '"', 'Need', 'Mozilla'),
#  ('exception', '"', 'Need', 'Mozilla', 'Firebird'),
#  ('"', 'Need', 'Mozilla', 'Firebird', 'newsgroup'),
#  ('Need', 'Mozilla', 'Firebird', 'newsgroup', 'Revive'),
#  ('Mozilla', 'Firebird', 'newsgroup', 'Revive', 'XUL'),
#  ('Firebird', 'newsgroup', 'Revive', 'XUL', 'preprocessor'),
#  ('newsgroup', 'Revive', 'XUL', 'preprocessor', 'Phoenix'),
#  ('Revive', 'XUL', 'preprocessor', 'Phoenix', 'needs'),
#  ('XUL', 'preprocessor', 'Phoenix', 'needs', 'talkback'),
#  ('preprocessor', 'Phoenix', 'needs', 'talkback', 'Navigation'),
#  ('Phoenix', 'needs', 'talkback', 'Navigation', 'toolbar'),
#  ('needs', 'talkback', 'Navigation', 'toolbar', 'is'),
#  ('talkback', 'Navigation', 'toolbar', 'is', 'completely'),
#  ('Navigation', 'toolbar', 'is', 'completely', 'blank'),
#  ('toolbar', 'is', 'completely', 'blank', 'Phoenix'),
#  ('is', 'completely', 'blank', 'Phoenix', 'refuses'),
#  ('completely', 'blank', 'Phoenix', 'refuses', 'to'),
#  ('blank', 'Phoenix', 'refuses', 'to', 'start'),
#  ('Phoenix', 'refuses', 'to', 'start', 'due'),
#  ('refuses', 'to', 'start', 'due', 'missing'),
#  ('to', 'start', 'due', 'missing', 'libstdc'),
#  ('start', 'due', 'missing', 'libstdc', '++-'),
#  ('due', 'missing', 'libstdc', '++-', 'libc6'),
#  ('missing', 'libstdc', '++-', 'libc6', '.'),
#  ('libstdc', '++-', 'libc6', '.', '2'),
#  ('++-', 'libc6', '.', '2', '-'),
#  ('libc6', '.', '2', '-', '2'),
#  ('.', '2', '-', '2', '.'),
#  ('2', '-', '2', '.', 'so'),
#  ('-', '2', '.', 'so', '.'),
#  ('2', '.', 'so', '.', '3'),
#  ('.', 'so', '.', '3', 'restore'),
#  ('so', '.', '3', 'restore', 'image'),
#  ...]
